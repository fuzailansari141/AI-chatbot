# %%
import pandas as pd
import numpy as np
import re

# %%
df=pd.read_csv("Brainloxinfo.csv")

# %%
df
# Out:
#                                          courses name  price per session
# 0                            LEARN SCRATCH PROGRAMING                 20  \
# 1                    LEARN CLOUD COMPUTING BASICS-AWS                 30
# 2                            LEARN MOBILE DEVELOPMENT                 20
# 3                  LEARN CORE JAVA PROGRAMMING ONLINE                 20
# 4                                      LEARN ROBOTICS                 20
# ..                                                ...                ...
# 62           Scratch Playground: Create a Space Game!                 20
# 63             Create Your Own Roblox Obstacle Course                 20
# 64           Java Minecraft Creative or Survival Mode                 20
# 65  AI Camp for Jobs & Business:Build Your own Cha...                 25
# 66  HTML, CSS, JavaScript Essentials: 5-Day Coding...                 13
#
#     no. of lessons  hour per session  Total price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   courses name       67 non-null     object
#  1   price per session  67 non-null     int64
#  2   no. of lessons     67 non-null     int64
#  3   hour per session   67 non-null     int64
#  4   Total price        67 non-null     int64
#  5   Description        67 non-null     object
#  6   Session names      14 non-null     object
# dtypes: int64(4), object(3)
# memory usage: 3.8+ KB

# %%
df['Session names'] = df['Session names'].fillna("Coming Soon")

# %%
df['Description']=df.Description.astype("str")

# %%
def clean(text):
    text=text.replace("\n","")
    text=text.replace("\t","")
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols & Pictographs
        "\U0001F680-\U0001F6FF"  # Transport & Map Symbols
        "\U0001F700-\U0001F77F"  # Alchemical Symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U0001F004-\U0001F0CF"  # Miscellaneous Symbols and Arrows
        "\U0001F170-\U0001F251"  # Enclosed Characters
        "]+",
        flags=re.UNICODE,
    )
    # Use sub() method to replace emojis with an empty string
    text_without_emojis = emoji_pattern.sub(r"", text)
    # Define a regular expression pattern to match symbols, signs, and operators
    pattern = r'[!@#$%^&*()_+={}\[\]:;"\'<>,.?/\|\\`~]'

    # Use the re.sub() function to remove the matched characters
    cleaned_string = re.sub(pattern, '', text_without_emojis)
    return cleaned_string

# %%
df["Description"]=df["Description"].apply(clean)

# %%
df["Session names"]=df["Session names"].apply(clean)

# %%
df
# Out:
#                                          courses name  price per session
# 0                            LEARN SCRATCH PROGRAMING                 20  \
# 1                    LEARN CLOUD COMPUTING BASICS-AWS                 30
# 2                            LEARN MOBILE DEVELOPMENT                 20
# 3                  LEARN CORE JAVA PROGRAMMING ONLINE                 20
# 4                                      LEARN ROBOTICS                 20
# ..                                                ...                ...
# 62           Scratch Playground: Create a Space Game!                 20
# 63             Create Your Own Roblox Obstacle Course                 20
# 64           Java Minecraft Creative or Survival Mode                 20
# 65  AI Camp for Jobs & Business:Build Your own Cha...                 25
# 66  HTML, CSS, JavaScript Essentials: 5-Day Coding...                 13
#
#     no. of lessons  hour per session  Total price
# ...

# %%
df.to_csv("brainloxinfoclean.csv",index=False)

# %%
df.columns
# Out:
# Index(['courses name', 'price per session', 'no. of lessons',
#        'hour per session', 'Total price', 'Description', 'Session names'],
#       dtype='object')
